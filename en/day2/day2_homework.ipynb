# %% [markdown]
# # 📝 homework Day 2: Building Agents with Google ADK
#
# **Translated English textpoints: 10 points**
#
# | Translated English text | points | content |
# |---------|-------|--------|
# | 1. Agent + Custom Tool | 3 | Translated English text Agent Translated English text tool Translated English text |
# | 2. RAG Agent | 3 | Translated English text Agent Translated English text Qdrant Translated English text |
# | 3. Workflow Agent | 2 | Translated English text Sequential/Parallel/Loop Translated English text pipeline |
# | 4. Translated English text | 2 | Translated English text |
#
# ### ⚠️ Translated English text
# - Translated English text **Translated English textstudents** → Translated English text
# - **Translated English text** cell Translated English text
# - Translated English text **Run Translated English text cell** Translated English text

# %% [markdown]
# ## 📦 Translated English text Dependencies

# %%
# %%time
# !pip install -q google-adk google-genai sentence-transformers qdrant-client langchain-text-splitters

import hashlib, os, json, random
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.runners import InMemoryRunner
from google.adk.sessions import InMemorySessionService
from google.genai import types
from sentence_transformers import SentenceTransformer
from qdrant_client import QdrantClient, models
from langchain_text_splitters import RecursiveCharacterTextSplitter

import warnings
warnings.filterwarnings('ignore')

print('✅ Translated English text!')

# %%
# %%time
# Translated English text Gemini API
try:
    from google.colab import userdata
    os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')
    print('✅ Translated English text API Key Translated English text Colab Secrets')
except Exception:
    api_key = input('🔑 Translated English text Gemini API Key: ')
    os.environ['GOOGLE_API_KEY'] = api_key

os.environ['GOOGLE_GENAI_USE_VERTEXAI'] = 'False'
print('✅ API Key Translated English text')

# %% [markdown]
# ## 🎓 Translated English textstudents

# %%
# ─── Translated English text ───
STUDENT_NAME = ''   # Translated English text 'Translated English text'
STUDENT_ID   = ''   # Translated English text '6512345678'
PHONE        = ''   # Translated English text '081-234-5678'
LINE_ID      = ''   # Translated English text 'somchai.j'

# ─── Translated English text (Translated English text) ───
assert len(STUDENT_ID) >= 5, '❌ Translated English textstudents!'
assert len(STUDENT_NAME) >= 2, '❌ Translated English text-Translated English text!'

print(f'✅ Translated English text-Translated English text: {STUDENT_NAME}')
print(f'✅ Translated English textstudents: {STUDENT_ID}')
print(f'📱 Translated English text: {PHONE}')
print(f'💬 LINE ID: {LINE_ID}')

# %% [markdown]
# ## 📄 Translated English text (Translated English text)
#
# > Translated English textstudents → Translated English text

# %%
# ===== Translated English text cell Translated English text =====
random.seed(int(hashlib.md5(STUDENT_ID.encode()).hexdigest()[:8], 16))

all_topics = [
    {'topic': 'healthcare', 'text': 'Translated English text AI Translated English text X-ray Translated English text 30 Translated English text 5 Translated English text Deep Learning Translated English text 95% Translated English text'},
    {'topic': 'banking', 'text': 'Translated English text KADE AI Assistant Translated English text RAG Translated English text 5 Translated English text 30 Translated English textThai languageTranslated English text'},
    {'topic': 'education', 'text': 'Translated English text RAG Translated English text-Translated English text PDF Translated English text 500 Translated English text vector embeddings Translated English text multilingual model Translated English textThai language'},
    {'topic': 'agriculture', 'text': 'Translated English text AI Translated English text 92% Translated English text 40%'},
    {'topic': 'logistics', 'text': 'Kerry Express Translated English text AI Translated English text 15% Translated English text 200 Translated English text Machine Learning Translated English text'},
    {'topic': 'retail', 'text': 'Translated English text AI Recommendation System Translated English text 25% Translated English text 10 Translated English text'},
    {'topic': 'energy', 'text': 'Translated English text (EGAT) Translated English text AI Translated English text 8% Translated English text Deep Learning Translated English text Smart Meter Translated English text'},
    {'topic': 'tourism', 'text': 'Translated English text. Translated English text AI Chatbot Translated English text 5 Translated English text 1 Translated English text call center Translated English text 60%'},
    {'topic': 'insurance', 'text': 'Translated English text AI Translated English text 7 Translated English text 1 Translated English text fraud Translated English text 90%'},
    {'topic': 'manufacturing', 'text': 'SCG Translated English text AI Translated English text Computer Vision Translated English text 30% Predictive Maintenance Translated English text 2 Translated English text'},
]

random.shuffle(all_topics)
my_topics = all_topics[:6]  # Translated English text 6 Translated English text 10 Translated English text

# Translated English text Qdrant
embed_model = SentenceTransformer('intfloat/multilingual-e5-large')
splitter = RecursiveCharacterTextSplitter(chunk_size=150, chunk_overlap=30)

my_chunks = []
my_sources = []
for item in my_topics:
    chunks = splitter.split_text(item['text'])
    for c in chunks:
        my_chunks.append(c)
        my_sources.append(item['topic'])

# Embed + Index
passages = [f'passage: {c}' for c in my_chunks]
embeddings = embed_model.encode(passages)
VECTOR_SIZE = embeddings.shape[1]

qdrant = QdrantClient(':memory:')
collection_name = f'hw2_{STUDENT_ID}'
qdrant.create_collection(
    collection_name=collection_name,
    vectors_config=models.VectorParams(size=VECTOR_SIZE, distance=models.Distance.COSINE)
)

points = [
    models.PointStruct(id=i, vector=embeddings[i].tolist(),
                       payload={'text': my_chunks[i], 'source': my_sources[i]})
    for i in range(len(my_chunks))
]
qdrant.upsert(collection_name=collection_name, points=points)

# Translated English text query Translated English text
query_pool = [
    'AI Translated English text',
    'Translated English text',
    'Translated English text Machine Learning',
    'Chatbot Translated English text',
    'Computer Vision Translated English text',
    'Translated English text Deep Learning',
]
random.shuffle(query_pool)
MY_QUERY = query_pool[0]

# Translated English text tool type
tool_types = [
    {'name': 'Translated English text ROI Translated English text AI', 'func': 'calculate_ai_roi', 'params': 'investment_baht: float, savings_per_year: float, years: int'},
    {'name': 'Translated English text AI', 'func': 'assess_ai_readiness', 'params': 'num_employees: int, has_data: bool, budget_million: float'},
    {'name': 'Translated English text Accuracy Score', 'func': 'calculate_accuracy', 'params': 'true_positives: int, false_positives: int, false_negatives: int, true_negatives: int'},
    {'name': 'Translated English text AI Model', 'func': 'recommend_model', 'params': 'task_type: str, data_size: str, budget: str'},
]
random.shuffle(tool_types)
MY_TOOL = tool_types[0]

# Workflow type
workflow_types = ['SequentialAgent', 'ParallelAgent', 'LoopAgent']
random.shuffle(workflow_types)
MY_WORKFLOW = workflow_types[0]

print(f'✅ Translated English text!')
print(f'   📊 Translated English text: {[t["topic"] for t in my_topics]}')
print(f'   📦 Chunks: {len(my_chunks)} | Collection: {collection_name}')
print(f'   🔍 Query Translated English text: "{MY_QUERY}"')
print(f'   🔧 Tool Translated English text: {MY_TOOL["name"]}')
print(f'   🔄 Workflow Translated English text: {MY_WORKFLOW}')

# %% [markdown]
# ## 🔧 Translated English text (Translated English text)

# %%
# ===== Translated English text cell Translated English text =====
async def chat_with_agent(agent, message, user_id='user_1', session_id=None):
    """Translated English text Agent Translated English text"""
    if session_id is None:
        session_id = f'session_{id(agent)}'
    runner = InMemoryRunner(agent=agent, app_name=agent.name)
    session = await runner.session_service.create_session(
        app_name=agent.name, user_id=user_id, session_id=session_id)
    content = types.Content(role='user', parts=[types.Part.from_text(text=message)])

    final_response = ''
    tool_calls = []
    async for event in runner.run_async(
        user_id=user_id, session_id=session.id, new_message=content):
        if event.content and event.content.parts:
            for part in event.content.parts:
                if part.text: final_response = part.text
                if part.function_call:
                    tool_calls.append(part.function_call.name)

    if tool_calls:
        print(f'  🔧 Tools: {tool_calls}')
    return final_response, session.id

print('✅ Translated English text chat Translated English text')

# %% [markdown]
# ---
# ## 🎯 Translated English text 1: Translated English text Agent + Custom Tool (3 points)
#
# Translated English text Agent Translated English text **2 tools**:
# 1. `search_knowledge` — Translated English text Qdrant (Translated English text)
# 2. **Custom Tool** — Translated English text (Translated English text `MY_TOOL`)
#
# ### Translated English text
# - 1 points: Translated English text custom tool Translated English text (Translated English text docstring + type hints + return dict)
# - 1 points: Translated English text Agent Translated English text 2 tools Translated English text
# - 1 points: Translated English text Agent Translated English text tool Translated English text

# %%
# RAG Tool (Translated English text — Translated English text)
def search_knowledge(query: str) -> dict:
    """Translated English text AI Translated English text
    
    Args:
        query: Translated English text
    """
    q_vec = embed_model.encode(f'query: {query}').tolist()
    results = qdrant.query_points(
        collection_name=collection_name, query=q_vec, limit=3).points
    return {
        'status': 'success',
        'results': [{'text': r.payload['text'], 'source': r.payload['source'],
                     'score': round(r.score, 4)} for r in results]
    }

print('✅ RAG Tool Translated English text')
print(f'\n📌 Tool Translated English text: {MY_TOOL["name"]}')
print(f'   Translated English text: {MY_TOOL["func"]}({MY_TOOL["params"]})')
print(f'   Translated English text return dict')

# %%
# Translated English text 1: Translated English text

# 💡 Hint:
#   1. Translated English text MY_TOOL Translated English text
#   2. Translated English text docstring (LLM Translated English text!)
#   3. Translated English text type hints
#   4. Translated English text return dict

# def MY_TOOL['func'](...) -> dict:
#     """Translated English text..."""
#     ...
#     return {...}



# Translated English text Agent Translated English text 2 tools
# my_agent = Agent(
#     name='my_agent',
#     model='gemini-2.5-flash',
#     tools=[search_knowledge, my_custom_tool]
# )



# Translated English text Tool Selection (Translated English text 3 Translated English text)
# 1. Translated English text RAG tool
# 2. Translated English text custom tool
# 3. Translated English text (Translated English text tool)
# await chat_with_agent(my_agent, '...')

# %% [markdown]
# ---
# ## 🎯 Translated English text 2: RAG Agent — Translated English text (3 points)
#
# Translated English text Agent Translated English text Qdrant Translated English text **query Translated English text**
#
# ### Translated English text
# - 1 points: Agent Translated English text + Translated English text Top-3 scores
# - 1 points: Translated English text
# - 1 points: Translated English text chunk Translated English text (3-5 Translated English text)

# %%
# Translated English text 2: Translated English text

print(f'🔍 Query Translated English text: "{MY_QUERY}"')

# 💡 Hint:
#   1. Translated English text Agent Translated English text instruction Translated English text search_knowledge
#   2. Translated English text MY_QUERY
#   3. Translated English text Top-3 scores
#   4. Translated English text (Translated English text AI)

# rag_agent = Agent(
#     name='rag_agent',
#     model='gemini-2.5-flash',
#     instruction='...',
#     tools=[search_knowledge]
# )
# response, _ = await chat_with_agent(rag_agent, MY_QUERY)
# print(response)

# %%
# Translated English text 2 (Translated English text): Translated English text
# Translated English text 3-5 Translated English text:
# 1. Translated English text chunks Translated English text?
# 2. Translated English text query Translated English text?
# 3. Translated English text?

MY_EXPLANATION_STEP2 = '''
(Translated English text)
'''
print(MY_EXPLANATION_STEP2)

# %% [markdown]
# ---
# ## 🎯 Translated English text 3: Workflow Agent (2 points)
#
# Translated English text Workflow Translated English text **pattern Translated English text** Translated English text `MY_WORKFLOW`
#
# ### Translated English text
# - 1 points: Translated English text Workflow Agent Translated English text pattern
# - 1 points: Translated English text + Translated English text

# %%
# Translated English text 3: Translated English text

print(f'🔄 Workflow Translated English text: {MY_WORKFLOW}')

# 💡 Hint Translated English text pattern:
#
# Translated English text SequentialAgent:
#   from google.adk.agents import SequentialAgent
#   pipeline = SequentialAgent(sub_agents=[agent1, agent2, agent3])
#   → Translated English text → Translated English text → Translated English text (Translated English text)
#
# Translated English text ParallelAgent:
#   from google.adk.agents import ParallelAgent
#   parallel = ParallelAgent(sub_agents=[search1, search2, search3])
#   → Translated English text
#
# Translated English text LoopAgent:
#   from google.adk.agents import LoopAgent
#   loop = LoopAgent(sub_agents=[writer, critic], max_iterations=3)
#   → Translated English text ↔ Translated English text



# Translated English text
# response, _ = await chat_with_agent(my_workflow, MY_QUERY)
# print(response)

# %% [markdown]
# ---
# ## 🎯 Translated English text 4: Translated English text (2 points)
#
# ### Translated English text
# - 1 points: Translated English text Workflow Translated English text — Translated English text? Translated English text/Translated English text?
# - 1 points: Translated English text 2 patterns — Translated English text pattern Translated English text?

# %%
# Translated English text 4: Translated English text

MY_EXPLANATION_STEP4 = f'''
Pattern Translated English text: {MY_WORKFLOW}

1. Translated English text {MY_WORKFLOW} Translated English text:
   (Translated English text)

2. Translated English text {MY_WORKFLOW}:
   (Translated English text)

3. Translated English text {MY_WORKFLOW}:
   (Translated English text)

4. Translated English text pattern Translated English text:
   (Translated English text)
'''
print(MY_EXPLANATION_STEP4)

# %% [markdown]
# ## ✅ Translated English text

# %%
# ===== Translated English text cell Translated English text =====
verify_hash = hashlib.sha256(f'{STUDENT_ID}_day2_hw'.encode()).hexdigest()[:12]
print('=' * 50)
print(f'👤 Translated English text-Translated English text: {STUDENT_NAME}')
print(f'🎓 Translated English textstudents: {STUDENT_ID}')
print(f'📱 Translated English text: {PHONE}')
print(f'💬 LINE ID: {LINE_ID}')
print(f'🔑 Verification Code: {verify_hash}')
print(f'📅 Translated English text: _________________ (Translated English text)')
print('=' * 50)
print()
print(f'📌 Translated English text:')
print(f'   Translated English text: {[t["topic"] for t in my_topics]}')
print(f'   Query: {MY_QUERY}')
print(f'   Tool: {MY_TOOL["name"]}')
print(f'   Workflow: {MY_WORKFLOW}')
print()
print('📋 Checklist Translated English text:')
print('  [ ] Translated English text')
print('  [ ] Translated English text 1: Translated English text Agent + Custom Tool + Translated English text 3 Translated English text')
print('  [ ] Translated English text 2: RAG Agent + Top-3 scores + Translated English text 3-5 Translated English text')
print('  [ ] Translated English text 3: Workflow Agent Translated English text pattern Translated English text')
print('  [ ] Translated English text 4: Translated English text + Translated English text')
print('  [ ] Translated English text cell run Translated English text')
